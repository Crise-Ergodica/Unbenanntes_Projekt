# %% [markdown]
# #### Imports

# %%
import pandas as pd
from sklearn import datasets

iris_data = datasets.load_iris()
irisDF = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
irisDF['target'] = iris_data.target

# %% [markdown]
# #### Estudo do dataset

# %%
irisDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
irisDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# #### Usando a função para fazer o resto automaticamente

# %%
from modulo import treino

# Com DataFrame
treino(
    caminho_csv=irisDF,
    target='target',
    nome='modeloIris',
    task='classification',  # Iris é classificação!
    numero_seed=42,
    iterações=15
)
# Out:
# <style type="text/css">
# #T_6b97e_row10_col0, #T_6b97e_row10_col1, #T_6b97e_row10_col2, #T_6b97e_row10_col3, #T_6b97e_row10_col4, #T_6b97e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6b97e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b97e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6b97e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6b97e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6b97e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6b97e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6b97e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b97e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b97e_row0_col0" class="data row0 col0" >0.0692</td>
#       <td id="T_6b97e_row0_col1" class="data row0 col1" >0.0455</td>
#       <td id="T_6b97e_row0_col2" class="data row0 col2" >0.2134</td>
#       <td id="T_6b97e_row0_col3" class="data row0 col3" >0.8898</td>
#       <td id="T_6b97e_row0_col4" class="data row0 col4" >0.0812</td>
#       <td id="T_6b97e_row0_col5" class="data row0 col5" >0.0392</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b97e_row1_col0" class="data row1 col0" >0.0126</td>
#       <td id="T_6b97e_row1_col1" class="data row1 col1" >0.0007</td>
#       <td id="T_6b97e_row1_col2" class="data row1 col2" >0.0257</td>
#       <td id="T_6b97e_row1_col3" class="data row1 col3" >0.9985</td>
#       <td id="T_6b97e_row1_col4" class="data row1 col4" >0.0126</td>
#       <td id="T_6b97e_row1_col5" class="data row1 col5" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b97e_row2_col0" class="data row2 col0" >0.1209</td>
#       <td id="T_6b97e_row2_col1" class="data row2 col1" >0.0748</td>
#       <td id="T_6b97e_row2_col2" class="data row2 col2" >0.2735</td>
#       <td id="T_6b97e_row2_col3" class="data row2 col3" >0.8669</td>
#       <td id="T_6b97e_row2_col4" class="data row2 col4" >0.1080</td>
#       <td id="T_6b97e_row2_col5" class="data row2 col5" >0.0828</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b97e_row3_col0" class="data row3 col0" >0.1102</td>
#       <td id="T_6b97e_row3_col1" class="data row3 col1" >0.1030</td>
#       <td id="T_6b97e_row3_col2" class="data row3 col2" >0.3209</td>
#       <td id="T_6b97e_row3_col3" class="data row3 col3" >0.8269</td>
#       <td id="T_6b97e_row3_col4" class="data row3 col4" >0.1285</td>
#       <td id="T_6b97e_row3_col5" class="data row3 col5" >0.2263</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b97e_row4_col0" class="data row4 col0" >0.2738</td>
#       <td id="T_6b97e_row4_col1" class="data row4 col1" >0.2610</td>
#       <td id="T_6b97e_row4_col2" class="data row4 col2" >0.5109</td>
#       <td id="T_6b97e_row4_col3" class="data row4 col3" >0.5356</td>
#       <td id="T_6b97e_row4_col4" class="data row4 col4" >0.2115</td>
#       <td id="T_6b97e_row4_col5" class="data row4 col5" >0.2677</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b97e_row5_col0" class="data row5 col0" >0.0844</td>
#       <td id="T_6b97e_row5_col1" class="data row5 col1" >0.0529</td>
#       <td id="T_6b97e_row5_col2" class="data row5 col2" >0.2300</td>
#       <td id="T_6b97e_row5_col3" class="data row5 col3" >0.9304</td>
#       <td id="T_6b97e_row5_col4" class="data row5 col4" >0.0979</td>
#       <td id="T_6b97e_row5_col5" class="data row5 col5" >0.1578</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b97e_row6_col0" class="data row6 col0" >0.0385</td>
#       <td id="T_6b97e_row6_col1" class="data row6 col1" >0.0044</td>
#       <td id="T_6b97e_row6_col2" class="data row6 col2" >0.0664</td>
#       <td id="T_6b97e_row6_col3" class="data row6 col3" >0.9892</td>
#       <td id="T_6b97e_row6_col4" class="data row6 col4" >0.0339</td>
#       <td id="T_6b97e_row6_col5" class="data row6 col5" >0.0387</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b97e_row7_col0" class="data row7 col0" >0.0501</td>
#       <td id="T_6b97e_row7_col1" class="data row7 col1" >0.0152</td>
#       <td id="T_6b97e_row7_col2" class="data row7 col2" >0.1233</td>
#       <td id="T_6b97e_row7_col3" class="data row7 col3" >0.9690</td>
#       <td id="T_6b97e_row7_col4" class="data row7 col4" >0.0565</td>
#       <td id="T_6b97e_row7_col5" class="data row7 col5" >0.0688</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6b97e_row8_col0" class="data row8 col0" >0.0946</td>
#       <td id="T_6b97e_row8_col1" class="data row8 col1" >0.0476</td>
#       <td id="T_6b97e_row8_col2" class="data row8 col2" >0.2181</td>
#       <td id="T_6b97e_row8_col3" class="data row8 col3" >0.9257</td>
#       <td id="T_6b97e_row8_col4" class="data row8 col4" >0.0835</td>
#       <td id="T_6b97e_row8_col5" class="data row8 col5" >0.0707</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6b97e_row9_col0" class="data row9 col0" >0.1269</td>
#       <td id="T_6b97e_row9_col1" class="data row9 col1" >0.0929</td>
#       <td id="T_6b97e_row9_col2" class="data row9 col2" >0.3048</td>
#       <td id="T_6b97e_row9_col3" class="data row9 col3" >0.8341</td>
#       <td id="T_6b97e_row9_col4" class="data row9 col4" >0.1219</td>
#       <td id="T_6b97e_row9_col5" class="data row9 col5" >0.0842</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6b97e_row10_col0" class="data row10 col0" >0.0981</td>
#       <td id="T_6b97e_row10_col1" class="data row10 col1" >0.0698</td>
#       <td id="T_6b97e_row10_col2" class="data row10 col2" >0.2287</td>
#       <td id="T_6b97e_row10_col3" class="data row10 col3" >0.8766</td>
#       <td id="T_6b97e_row10_col4" class="data row10 col4" >0.0936</td>
#       <td id="T_6b97e_row10_col5" class="data row10 col5" >0.1061</td>
#     </tr>
#     <tr>
#       <th id="T_6b97e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6b97e_row11_col0" class="data row11 col0" >0.0682</td>
#       <td id="T_6b97e_row11_col1" class="data row11 col1" >0.0718</td>
#       <td id="T_6b97e_row11_col2" class="data row11 col2" >0.1323</td>
#       <td id="T_6b97e_row11_col3" class="data row11 col3" >0.1273</td>
#       <td id="T_6b97e_row11_col4" class="data row11 col4" >0.0528</td>
#       <td id="T_6b97e_row11_col5" class="data row11 col5" >0.0791</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_62079_row10_col0, #T_62079_row10_col1, #T_62079_row10_col2, #T_62079_row10_col3, #T_62079_row10_col4, #T_62079_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_62079">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62079_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_62079_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_62079_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_62079_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_62079_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_62079_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62079_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_62079_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_62079_row8_col0" class="data row8 col0" >0.1162</td>
#       <td id="T_62079_row8_col1" class="data row8 col1" >0.0357</td>
#       <td id="T_62079_row8_col2" class="data row8 col2" >0.1888</td>
#       <td id="T_62079_row8_col3" class="data row8 col3" >0.9443</td>
#       <td id="T_62079_row8_col4" class="data row8 col4" >0.0799</td>
#       <td id="T_62079_row8_col5" class="data row8 col5" >0.0859</td>
#     </tr>
#     <tr>
#       <th id="T_62079_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_62079_row9_col0" class="data row9 col0" >0.1898</td>
#       <td id="T_62079_row9_col1" class="data row9 col1" >0.1206</td>
#       <td id="T_62079_row9_col2" class="data row9 col2" >0.3473</td>
#       <td id="T_62079_row9_col3" class="data row9 col3" >0.7847</td>
#       <td id="T_62079_row9_col4" class="data row9 col4" >0.1511</td>
#       <td id="T_62079_row9_col5" class="data row9 col5" >0.1068</td>
#     </tr>
#     <tr>
#       <th id="T_62079_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_62079_row10_col0" class="data row10 col0" >0.1250</td>
#       <td id="T_62079_row10_col1" class="data row10 col1" >0.0584</td>
#       <td id="T_62079_row10_col2" class="data row10 col2" >0.2106</td>
#       <td id="T_62079_row10_col3" class="data row10 col3" >0.8953</td>
#       <td id="T_62079_row10_col4" class="data row10 col4" >0.0935</td>
#       <td id="T_62079_row10_col5" class="data row10 col5" >0.1056</td>
#     </tr>
#     <tr>
#       <th id="T_62079_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_62079_row11_col0" class="data row11 col0" >0.0731</td>
#       <td id="T_62079_row11_col1" class="data row11 col1" >0.0642</td>
#       <td id="T_62079_row11_col2" class="data row11 col2" >0.1187</td>
#       <td id="T_62079_row11_col3" class="data row11 col3" >0.1131</td>
#       <td id="T_62079_row11_col4" class="data row11 col4" >0.0456</td>
#       <td id="T_62079_row11_col5" class="data row11 col5" >0.0740</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# Transformation Pipeline and Model Successfully Saved
# ✅ Modelo 'modeloIris' treinado e salvo com sucesso!
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['sepal length (cm)',
#                                              'sepal width (cm)',
#                                              'petal length (cm)',
#                                              'petal width (cm)'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator',
#                  GradientBoostingRegressor(learning_rate=0.05, max_depth=6,
#                                            max_features='sqrt',
#                                            min_impurity_decrease=0.3,
#                                            min_samples_leaf=4,
#                                            min_samples_split=10,
#                                            n_estimators=270, random_state=42,
#                                            subsample=0.7))])

# %%
from modulo import teste

resultado = teste(
    caminho_csv=irisDF,
    modelo_nome='modeloIris',
    task='classification'
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from modulo import teste
# ----> 3 resultado = teste(
#       4     caminho_csv=irisDF,
#       5     modelo_nome='modeloIris',
#       6     task='classification'
#       7     )
#
# File ~/PycharmProjects/Unbenanntes Projekt/modulo/modeling/teste.py:72, in teste(caminho_csv, modelo_nome, task)
#      70         resultado = predict_reg(modelo, data=dados_teste)
#      71     else:
# ---> 72         modelo = load_clf(modelo_nome)
#      73         resultado = predict_clf(modelo, data=dados_teste)
#      74 except FileNotFoundError:
#
# NameError: name 'load_clf' is not defined

# %% [markdown]
# ### Tabela Confusão

# %%
from modulo import matriz_confusao
matriz_confusao(resultado)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 from modulo import matriz_confusao
#       2 matriz_confusao(resultado)
#
# ImportError: cannot import name 'matriz_confusao' from 'modulo' (/home/aurora/PycharmProjects/Unbenanntes Projekt/modulo/__init__.py)
