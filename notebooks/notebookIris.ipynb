# %% [markdown]
# #### Imports

# %%
import pandas as pd
from sklearn import datasets

iris_data = datasets.load_iris()
irisDF = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
irisDF['target'] = iris_data.target

# %% [markdown]
# #### Estudo do dataset

# %%
irisDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
irisDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# #### Usando a função para fazer o resto automaticamente

# %%
from modulo import treino

# Com DataFrame
treino(
    caminho_csv=irisDF,
    target='target',
    nome='modeloIris',
    task='classification',
    numero_seed=42,
    iterações=15,
    algoritmo='gbc'
)
# Out:
# <style type="text/css">
# #T_f2c67_row10_col0, #T_f2c67_row10_col1, #T_f2c67_row10_col2, #T_f2c67_row10_col3, #T_f2c67_row10_col4, #T_f2c67_row10_col5, #T_f2c67_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f2c67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2c67_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f2c67_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f2c67_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f2c67_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f2c67_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f2c67_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f2c67_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2c67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2c67_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_f2c67_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_f2c67_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_f2c67_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_f2c67_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_f2c67_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_f2c67_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2c67_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_f2c67_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_f2c67_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_f2c67_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_f2c67_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_f2c67_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_f2c67_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2c67_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_f2c67_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_f2c67_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_f2c67_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_f2c67_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_f2c67_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_f2c67_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2c67_row3_col0" class="data row3 col0" >0.9091</td>
#       <td id="T_f2c67_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_f2c67_row3_col2" class="data row3 col2" >0.9091</td>
#       <td id="T_f2c67_row3_col3" class="data row3 col3" >0.9273</td>
#       <td id="T_f2c67_row3_col4" class="data row3 col4" >0.9076</td>
#       <td id="T_f2c67_row3_col5" class="data row3 col5" >0.8625</td>
#       <td id="T_f2c67_row3_col6" class="data row3 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2c67_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_f2c67_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_f2c67_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_f2c67_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_f2c67_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_f2c67_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_f2c67_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2c67_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_f2c67_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_f2c67_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_f2c67_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_f2c67_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_f2c67_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_f2c67_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2c67_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_f2c67_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_f2c67_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_f2c67_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_f2c67_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_f2c67_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_f2c67_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2c67_row7_col0" class="data row7 col0" >0.8000</td>
#       <td id="T_f2c67_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_f2c67_row7_col2" class="data row7 col2" >0.8000</td>
#       <td id="T_f2c67_row7_col3" class="data row7 col3" >0.8800</td>
#       <td id="T_f2c67_row7_col4" class="data row7 col4" >0.7750</td>
#       <td id="T_f2c67_row7_col5" class="data row7 col5" >0.6970</td>
#       <td id="T_f2c67_row7_col6" class="data row7 col6" >0.7435</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2c67_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_f2c67_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_f2c67_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_f2c67_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_f2c67_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_f2c67_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_f2c67_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2c67_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_f2c67_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_f2c67_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_f2c67_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_f2c67_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_f2c67_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_f2c67_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f2c67_row10_col0" class="data row10 col0" >0.9518</td>
#       <td id="T_f2c67_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_f2c67_row10_col2" class="data row10 col2" >0.9518</td>
#       <td id="T_f2c67_row10_col3" class="data row10 col3" >0.9660</td>
#       <td id="T_f2c67_row10_col4" class="data row10 col4" >0.9487</td>
#       <td id="T_f2c67_row10_col5" class="data row10 col5" >0.9270</td>
#       <td id="T_f2c67_row10_col6" class="data row10 col6" >0.9352</td>
#     </tr>
#     <tr>
#       <th id="T_f2c67_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f2c67_row11_col0" class="data row11 col0" >0.0658</td>
#       <td id="T_f2c67_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_f2c67_row11_col2" class="data row11 col2" >0.0658</td>
#       <td id="T_f2c67_row11_col3" class="data row11 col3" >0.0436</td>
#       <td id="T_f2c67_row11_col4
# <style type="text/css">
# #T_486a9_row10_col0, #T_486a9_row10_col1, #T_486a9_row10_col2, #T_486a9_row10_col3, #T_486a9_row10_col4, #T_486a9_row10_col5, #T_486a9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_486a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_486a9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_486a9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_486a9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_486a9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_486a9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_486a9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_486a9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_486a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_486a9_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_486a9_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_486a9_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_486a9_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_486a9_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_486a9_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_486a9_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_486a9_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_486a9_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_486a9_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_486a9_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_486a9_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_486a9_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_486a9_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_486a9_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_486a9_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_486a9_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_486a9_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_486a9_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_486a9_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_486a9_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_486a9_row3_col0" class="data row3 col0" >0.9091</td>
#       <td id="T_486a9_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_486a9_row3_col2" class="data row3 col2" >0.9091</td>
#       <td id="T_486a9_row3_col3" class="data row3 col3" >0.9273</td>
#       <td id="T_486a9_row3_col4" class="data row3 col4" >0.9076</td>
#       <td id="T_486a9_row3_col5" class="data row3 col5" >0.8625</td>
#       <td id="T_486a9_row3_col6" class="data row3 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_486a9_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_486a9_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_486a9_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_486a9_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_486a9_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_486a9_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_486a9_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_486a9_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_486a9_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_486a9_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_486a9_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_486a9_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_486a9_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_486a9_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_486a9_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_486a9_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_486a9_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_486a9_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_486a9_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_486a9_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_486a9_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_486a9_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_486a9_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_486a9_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_486a9_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_486a9_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_486a9_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_486a9_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_486a9_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_486a9_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_486a9_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_486a9_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_486a9_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_486a9_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_486a9_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_486a9_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_486a9_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_486a9_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_486a9_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_486a9_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_486a9_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_486a9_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_486a9_row10_col0" class="data row10 col0" >0.9718</td>
#       <td id="T_486a9_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_486a9_row10_col2" class="data row10 col2" >0.9718</td>
#       <td id="T_486a9_row10_col3" class="data row10 col3" >0.9780</td>
#       <td id="T_486a9_row10_col4" class="data row10 col4" >0.9712</td>
#       <td id="T_486a9_row10_col5" class="data row10 col5" >0.9573</td>
#       <td id="T_486a9_row10_col6" class="data row10 col6" >0.9609</td>
#     </tr>
#     <tr>
#       <th id="T_486a9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_486a9_row11_col0" class="data row11 col0" >0.0431</td>
#       <td id="T_486a9_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_486a9_row11_col2" class="data row11 col2" >0.0431</td>
#       <td id="T_486a9_row11_col3" class="data row11 col3" >0.0337</td>
#       <td id="T_486a9_row11_col4
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# Transformation Pipeline and Model Successfully Saved
# ✅ Modelo 'modeloIris' treinado e salvo com sucesso!
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['sepal length (cm)',
#                                              'sepal width (cm)',
#                                              'petal length (cm)',
#                                              'petal width (cm)'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  TransformerWr...
#                                             criterion='friedman_mse', init=None,
#                                             learning_rate=0.0001,
#                                             loss='log_loss', max_depth=9,
#                                             max_features='sqrt',
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.3,
#                                             min_samples_leaf=5,
#                                             min_samples_split=5,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=260,
#                                             n_iter_no_change=None,
#                                             random_state=42, subsample=0.35,
#                                             tol=0.0001, validation_fraction=0.1,
#                                             verbose=0, warm_start=False))],
#          verbose=False)

# %%
from modulo import teste

resultado = teste(
    caminho_csv=irisDF,
    modelo_nome='modeloIris',
    task='classification'
    )
# Out:
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_a31b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a31b9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a31b9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a31b9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a31b9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a31b9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a31b9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a31b9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a31b9_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a31b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a31b9_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a31b9_row0_col1" class="data row0 col1" >0.9667</td>
#       <td id="T_a31b9_row0_col2" class="data row0 col2" >0.9976</td>
#       <td id="T_a31b9_row0_col3" class="data row0 col3" >0.9667</td>
#       <td id="T_a31b9_row0_col4" class="data row0 col4" >0.9668</td>
#       <td id="T_a31b9_row0_col5" class="data row0 col5" >0.9667</td>
#       <td id="T_a31b9_row0_col6" class="data row0 col6" >0.9500</td>
#       <td id="T_a31b9_row0_col7" class="data row0 col7" >0.9501</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Teste do modelo 'modeloIris' concluído com sucesso!

# %% [markdown]
# ### Tabela Confusão

# %%
from modulo import matriz_confusao
matriz_confusao(resultado)
# Out:
# ======================================================================
# ✅ MATRIZ DE CONFUSÃO GERADA COM SUCESSO!
# ======================================================================
#
#  MÉTRICAS GLOBAIS:
# Acurácia: 96.67%
# Precision (Macro): 96.68%
# Recall (Macro): 96.67%
# F1-Score (Macro): 96.67%
# array([[50,  0,  0],
#        [ 0, 47,  3],
#        [ 0,  2, 48]])
